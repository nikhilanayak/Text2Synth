# %% [markdown]
# # CTAG on the latest Colab GPU runtime
#
# Select **Runtime → Change runtime type → T4 GPU**, then run each cell in order. The bootstrap preserves Colab's CUDA-enabled JAX and PyTorch wheels, installs the compatible numerical layers, and downloads the official CLAP checkpoint.

# %%
# %cd /content
![ -d Synthesizer/.git ] || git clone --depth 1 https://github.com/nikhilanayak/Synthesizer.git
# %cd /content/Synthesizer
# !git pull --ff-only
# %cd /content/Synthesizer/ctag-repro
# !bash tools/colab_bootstrap.sh
# Out:
# /content
# Cloning into 'Synthesizer'...
# fatal: could not read Username for 'https://github.com': No such device or address
# fatal: expected flush after ref listing
# [Errno 2] No such file or directory: '/content/Synthesizer'
# /content
# fatal: not a git repository (or any of the parent directories): .git
# [Errno 2] No such file or directory: '/content/Synthesizer/ctag-repro'
# /content
# bash: tools/colab_bootstrap.sh: No such file or directory

# %%
# !ctag doctor --require-gpu
# Out:
# {
#   "accelerators": {
#     "jax_platforms": [
#       "gpu"
#     ],
#     "shared_gpu_memory_safe": true,
#     "torch_cuda_available": true,
#     "torch_cuda_version": "12.8",
#     "torch_device": "Tesla T4"
#   },
#   "compatible": true,
#   "expected": {
#     "evosax": "==0.3.1",
#     "flax": "==0.12.9",
#     "jax": "==0.11.1",
#     "jaxlib": "==0.11.1",
#     "laion-clap": "==1.1.7",
#     "numba": "==0.61.2",
#     "numpy": "==2.1.3",
#     "pandas": "==2.2.3",
#     "python": "==3.13.*",
#     "scipy": "==1.16.3",
#     "synthax": "==0.2.2",
#     "torch": "==2.11.0",
#     "torchvision": "==0.26.0",
#     "transformers": "==5.16.1"
#   },
#   "issues": [],
#   "require_gpu": true,
#   "sys_executable": "/usr/bin/python3",
#   "versions": {
#     "evosax": "0.3.1",
#     "flax": "0.12.9",
#     "jax": "0.11.1",
#     "jaxlib": "0.11.1",
#     "laion-clap": "1.1.7",
#     "numba": "0.61.2",
#     "numpy": "2.1.3",
#     "pandas": "2.2.3",
#     "python": "3.13.15",
#     "scipy": "1.16.3",
#     "synthax": "0.2.2",
#     "torch": "2.11.0+cu128",
#     "torchvision": "0.26.0+cu128",
#     "transformers": "5.16.1"
#   }
# }

# %% [markdown]
# ## Short end-to-end GPU test
# This evaluates 100 candidates and does not write artifacts.

# %%
# !time ctag generate --profile smoke --prompt "train horn" --population 10 --iterations 10 --device cuda --no-artifacts
# Out:
# {
#   "checkpoint": "checkpoints/630k-audioset-best.pt",
#   "control_rate": 480,
#   "device": "cuda",
#   "duration_seconds": 2.0,
#   "iterations": 10,
#   "log_every": 10,
#   "mean_decay": 0.0,
#   "output_root": "runs",
#   "population_size": 10,
#   "profile": "smoke",
#   "runs_per_prompt": 1,
#   "sample_rate": 48000,
#   "seed": 42,
#   "sigma_init": 0.2693048095331496
# }
# /usr/local/lib/python3.13/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# /usr/local/lib/python3.13/dist-packages/torch/functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4381.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# config.json: 100% 481/481 [00:00<00:00, 2.00MB/s]
#
# model.safetensors: downloading bytes:  31% 156M/499M [00:01<00:01, 215MB/s, 12.3MB/s  ]
# model.safetensors: downloading bytes:  49% 244M/499M [00:01<00:01, 179MB/s, 21.3MB/s  ]
# model.safetensors: downloading bytes:  65% 324M/499M [00:01<00:00, 219MB/s, 26.6MB/s  ]
# model.safetensors: reconstructing file:  81% 402M/499M [00:02<00:00, 225MB/s, 25.5MB/s  ]
# model.safetensors: downloading bytes: 100% 335M/335M [00:04<00:00, 76.8MB/s, 30.3MB/s  ]
# model.safetensors: reconstructing file: 100% 499M/499M [00:04<00:00, 114MB/s, 39.1MB/s  ]
# Loading weights: 100% 197/197 [00:00<00:00, 4251.52it/s]
# [transformers] RobertaModel LOAD REPORT from: roberta-base
# Key                       | Status     |
# --------------------------+------------+-
# lm_head.bias              | UNEXPECTED |
# lm_head.layer_norm.weight | UNEXPECTED |
# lm_head.dense.bias        | UNEXPECTED |
# lm_head.dense.weight      | UNEXPECTED |
# lm_head.layer_norm.bias   | UNEXPECTED |
# pooler.dense.weight       | MISSING    |
# pooler.dense.bias         | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# [train horn] 1/10 best_fitness=0.000000
# [train horn] 10/10 best_fitness=-0.168109
# [
#   {
#     "artifact_dir": null,
#     "best_fitness": -0.16810885071754456,
#     "best_similarity": 0.16810885071754456,
#     "prompt": "train horn",
#     "run_index": 0,
#     "timings_seconds": {
#       "audio_embedding": 1.4574622209999006,
#       "scoring": 0.0013372189998790418,
#       "search": 3.6720788100000163,
#       "synthesis": 4.279011200000014,
#       "text_embedding": 0.3692855230000305
#     }
#   }
# ]
#
# real	1m4.156s
# user	0m57.537s
# sys	0m7.432s

# %% [markdown]
# ## Full paper-budget search
# This evaluates 15,000 two-second candidates and saves the best WAV and patch under `runs/`.

# %%
# !time ctag reproduce --prompt "train horn" --device cuda
# Out:
# /bin/bash: line 1: ctag: command not found
#
# real	0m0.001s
# user	0m0.000s
# sys	0m0.000s
